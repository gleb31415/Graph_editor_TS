# %%
# -*- coding: utf-8 -*-
import zipfile, io, os, re, time, sys

TASK_NAMES = {
    "physics__7.avgspd.zip": {
        "1": "Половинки",
        "2": "Катер",
        "3": "Плывем по течению",
        "4": "Смотрите под ноги",
        "5": "Бег по кругу",
        "6": "График средней скорости от пути",
        "7": "Бездорожье"
    },
    "physics__7.force.zip": {
        "1": "Перетягивание каната"
    },
    "physics__7arhimed.zip": {
        "1": "Шар повесили",
        "2": "Топим пластилином",
        "3": "На границе",
        "4": "Куб не тонет",
        "5": "Поплыли",
        "6": "Ледяные весы"
    },
    "physics__7friction.zip": {
        "1": "Куда везем мы кирпичи",
        "2": "Никак не сдвинуть",
        "3": "Снова ящик",
        "4": "Зажали"
    },
    "physics__7graphs.zip": {
        "Максимальная скорость": "Максимальная скорость",
        "Скорость от пути": "Скорость от пути",
        "Максимальное опережение": "Максимальное опережение",
        "Средняя скорость от пути": "Средняя скорость от пути"
    },
    "physics__7kinblok.zip": {
        "1": "Нить на блоке",
        "2": "Эвакуатор"
    },
    "physics__7mgN.zip": {
        "1": "Вес",
        "2": "Нормальная Реакция",
        "3": "Шары приятягиваются",
        "4": "Луннная гравитация",
        "5": "Солнце и земля"
    },
    "physics__7pressure.zip": {
        "1": "Давление мальчика",
        "2": "Большой столб",
        "3": "Масло и водица",
        "4": "Давить на воду",
        "5": "Намудрили",
        "6": "Пластилин на дне"
    },
    "physics__7rpo.zip": {
        "1": "Почти Феррари",
        "2": "Длинный поезд",
        "3": "График x(t)"
    },
    "physics__7springs.zip": {
        "1": "Растяжка",
        "2": "2 пружины последоваительно",
        "3": "теперь параллельно",
        "4": "2 хорошо, а 3 лучше",
        "5": "Разрезали поровну",
        "6": "Увеличиваем жесткость"
    },
    "physics__7statblock.zip": {
        "Два блока": "Два блока",
        "Змейкой": "Змейкой",
        "Ограниченное равновесие": "Ограниченное равновесие",
        "Лесенка": "Лесенка",
        "Намудрили": "Намудрили"
    },
    "physics__7torque.zip": {
        "1": "Равновесие",
        "2": "Груз на палке",
        "3": "Скизифова улитка",
        "4": "Соломинка",
        "5": "рычаг блок и нить"
    },
    "physics__7turmech.zip": {
        "Потерянная информация": "Потерянная информация",
        "Сила на дно": "Сила на дно",
        "Перемещение груза": "Перемещение груза",
        "Люди на рычагах": "Люди на рычагах",
        "Смещение груза": "Смещение груза"
    },
    "physics__7work.zip": {
        "1": "Работа крана",
        "2": "День на стройке",
        "3": "Полезный блок"
    }
}

SOURCE_DIR = "."
OUTPUT_DIR = "./processed"
os.makedirs(OUTPUT_DIR, exist_ok=True)

ANSWERINPUT_RE = re.compile(r'(\\answerinput)\s*\{[^}]*\}')
ANSWERINPUT_CAPTURE_RE = re.compile(r'\\(answerinput|answerinput_test)\s*\{([^}]*)\}')

def extract_answerinputs(content: str):
    return [m.group(2).strip() for m in ANSWERINPUT_CAPTURE_RE.finditer(content)]

def clean_tex(content: str) -> str:
    return ANSWERINPUT_RE.sub(r'\1{}', content)

def is_html(name: str) -> bool:
    return name.lower().endswith(".html")

def rename_tex_to_main_zip(single_problem_zip: zipfile.ZipFile, new_zip: zipfile.ZipFile):
    html_removed = 0
    cleaned_cnt = 0
    found_tex = None
    tex_basename_for_name = None
    answerinputs_found = []

    for nm in single_problem_zip.namelist():
        if nm.endswith("/") or is_html(nm):
            continue
        if nm.lower().endswith(".tex") and found_tex is None:
            found_tex = nm
            tex_basename_for_name = os.path.splitext(os.path.basename(nm))[0]

    new_main_path = None
    for nm in single_problem_zip.namelist():
        if nm.endswith("/"):
            continue
        if is_html(nm):
            html_removed += 1
            continue

        data = single_problem_zip.read(nm)
        if nm == found_tex:
            text = data.decode("utf-8", errors="ignore")
            answerinputs_found = extract_answerinputs(text)
            new_text = clean_tex(text)
            if new_text != text:
                cleaned_cnt += 1
            data = new_text.encode("utf-8")
            dname = os.path.dirname(nm)
            new_main_path = os.path.join(dname, "main.tex") if dname else "main.tex"
            new_zip.writestr(new_main_path, data)
        else:
            new_zip.writestr(nm, data)

    return new_main_path, tex_basename_for_name, html_removed, cleaned_cnt, answerinputs_found

def process_root_zip(root_zip_name: str):
    root_html_removed = 0
    inner_html_removed = 0
    tex_cleaned = 0
    tasks_written = 0

    root_zip_path = os.path.join(SOURCE_DIR, root_zip_name)
    print(f"📦 Обработка архива: {root_zip_name}")

    with zipfile.ZipFile(root_zip_path, 'r') as root_zip:
        problems_member = next((nm for nm in root_zip.namelist() if nm.endswith("problems.zip")), None)
        if not problems_member:
            print("  ⚠️ problems.zip не найден — пропуск архива.")
            return (0, 0, 0, 0)

        problems_data = io.BytesIO(root_zip.read(problems_member))
        with zipfile.ZipFile(problems_data, 'r') as problems_zip:
            problem_zips = [p for p in problems_zip.namelist() if p.lower().endswith(".zip")]
            html_in_problems = [p for p in problems_zip.namelist() if is_html(p)]
            inner_html_removed += len(html_in_problems)

            new_problems_buffer = io.BytesIO()
            with zipfile.ZipFile(new_problems_buffer, 'w', compression=zipfile.ZIP_DEFLATED) as new_problems_zip:
                for idx, p in enumerate(problem_zips, start=1):
                    tasks_written += 1
                    inner_bytes = io.BytesIO(problems_zip.read(p))
                    with zipfile.ZipFile(inner_bytes, 'r') as single_problem_zip:
                        new_problem_buf = io.BytesIO()
                        with zipfile.ZipFile(new_problem_buf, 'w', compression=zipfile.ZIP_DEFLATED) as new_problem_zip:
                            new_main_path, tex_base, html_removed, cleaned_cnt, answers = rename_tex_to_main_zip(
                                single_problem_zip, new_problem_zip
                            )
                            inner_html_removed += html_removed
                            tex_cleaned += cleaned_cnt

                            mapping = TASK_NAMES.get(root_zip_name, {})
                            orig_key = os.path.splitext(os.path.basename(p))[0]
                            if mapping:
                                name_value = mapping.get(orig_key, tex_base or orig_key)
                                name_source = "словарь7" if orig_key in mapping else ("имя .tex" if tex_base else "имя zip")
                            else:
                                name_value = tex_base or orig_key
                                name_source = "имя .tex" if tex_base else "имя zip"

                            new_problem_zip.writestr("name.txt", name_value)
                            new_problem_zip.writestr("index.txt", str(idx))

                        new_name = f"{idx}.zip"
                        new_problems_zip.writestr(new_name, new_problem_buf.getvalue())

                        root_key = os.path.splitext(root_zip_name)[0]  # имя архива без .zip
                        print(f"    │    • problem_{root_key}_{idx}: ответы -> {answers if answers else '(нет)'}")

            out_zip_path = os.path.join(OUTPUT_DIR, root_zip_name)
            with zipfile.ZipFile(out_zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as out_zip:
                for f in root_zip.namelist():
                    if is_html(f):
                        root_html_removed += 1
                        continue
                    if f == problems_member:
                        out_zip.writestr(f, new_problems_buffer.getvalue())
                    else:
                        out_zip.writestr(f, root_zip.read(f))

    print(f"  ✓ Готово: {root_zip_name}")
    print(f"    • Задач перепаковано: {tasks_written}")
    print(f"    • Удалено .html: {root_html_removed+inner_html_removed}")
    print(f"    • Очищено answerinput: {tex_cleaned}")
    print(f"    • Результат: {os.path.join(OUTPUT_DIR, root_zip_name)}")
    return (1, tasks_written, root_html_removed+inner_html_removed, tex_cleaned)

def main():
    start = time.time()
    archives_total = 0
    tasks_total = 0
    html_removed_total = 0
    tex_cleaned_total = 0
    zips = [z for z in sorted(os.listdir(SOURCE_DIR)) if z.lower().endswith(".zip")]
    if not zips:
        print("⚠️ В каталоге нет .zip архивов.")
        return

    print(f"Найдено архивов: {len(zips)}. Выходная папка: {OUTPUT_DIR}")
    for z in zips:
        a, t, h, c = process_root_zip(z)
        archives_total += a
        tasks_total += t
        html_removed_total += h
        tex_cleaned_total += c

    print("\n==================== ИТОГО ====================")
    print(f"• Обработано архивов: {archives_total}")
    print(f"• Всего задач: {tasks_total}")
    print(f"• Удалено .html всего: {html_removed_total}")
    print(f"• Очищено answerinput: {tex_cleaned_total}")
    print(f"• Время: {time.time()-start:.2f} c")
    print(f"• Папка с результатом: {OUTPUT_DIR}")

if __name__ == "__main__":
    main()
# Out:
# Найдено архивов: 35. Выходная папка: ./processed
#
# ================================================================================
# 📦 Обработка архива: physics__10AU.zip
#   • Найдено задач: 3
#     ├─ Задача: Простой процесс.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Простой процесс» (имя .tex)
#     │    • problem_physics__10AU_1: ответы -> ['57.2']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Необычный график.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Необычный график» (имя .tex)
#     │    • problem_physics__10AU_2: ответы -> ['16.0']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Азот.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Азот» (имя .tex)
#     │    • problem_physics__10AU_3: ответы -> ['35']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10AU.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10AU.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10Entropy.zip
#   • Найдено задач: 2
#     ├─ Задача: Энтропия процесса.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Энтропия процесса» (имя .tex)
#     │    • problem_physics__10Entropy_1: ответы -> ['8.6']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: КПД через энтропию.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «КПД через энтропию» (имя .tex)
#     │    • problem_physics__10Entropy_2: ответы -> ['45']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10Entropy.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10Entropy.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10G.zip
#   • Найдено задач: 3
#     ├─ Задача: На экране.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «На экране» (имя .tex)
#     │    • problem_physics__10G_1: ответы -> ['2.6']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Увеличение среднего.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Увеличение среднего» (имя .tex)
#     │    • problem_physics__10G_2: ответы -> ['$15$']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Таракашка.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Таракашка» (имя .tex)
#     │    • problem_physics__10G_3: ответы -> ['0.8', '53', '0.05']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10G.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10G.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10KK.zip
#   • Найдено задач: 3
#     ├─ Задача: Критерий уменьшения.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Критерий уменьшения» (имя .tex)
#     │    • problem_physics__10KK_1: ответы -> ['$c > 4R$; $c < 4R$; $c > R$; $c = 2R$']
#     │    • Удалено .html: 1
#     ├─ Задача: Критическая точка.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Критическая точка» (имя .tex)
#     │    • problem_physics__10KK_2: ответы -> ['1350']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Изменение кипения.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Изменение кипения» (имя .tex)
#     │    • problem_physics__10KK_3: ответы -> ['77']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10KK.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10KK.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10Tkarno.zip
#   • Найдено задач: 1
#     ├─ Задача: Рабочий пар.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Рабочий пар» (имя .tex)
#     │    • problem_physics__10Tkarno_1: ответы -> ['6.2']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10Tkarno.zip
#     • Задач перепаковано: 1
#     • Удалено .html: 2
#     • Очищено answerinput: 1
#     • Результат: ./processed/physics__10Tkarno.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10VNT.zip
#   ⚠️ problems.zip не найден — пропуск архива.
#
# ================================================================================
# 📦 Обработка архива: physics__10adiabatic.zip
#   • Найдено задач: 3
#     ├─ Задача: По молю гелия.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «По молю гелия» (имя .tex)
#     │    • problem_physics__10adiabatic_1: ответы -> ['10.8']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Малое изменение.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Малое изменение» (имя .tex)
#     │    • problem_physics__10adiabatic_2: ответы -> ['0.6']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Два гелия.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Два гелия» (имя .tex)
#     │    • problem_physics__10adiabatic_3: ответы -> ['12.5']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10adiabatic.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10adiabatic.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10conduct.zip
#   • Найдено задач: 4
#     ├─ Задача: Шар в однородном поле.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Шар в однородном поле» (имя .tex)
#     │    • problem_physics__10conduct_1: ответы -> ['75', '19', '19', '2.12']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Незаряженный шар.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Незаряженный шар» (имя .tex)
#     │    • problem_physics__10conduct_2: ответы -> ['-6.3']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Сферический проводник.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Сферический проводник» (имя .tex)
#     │    • problem_physics__10conduct_3: ответы -> ['540', '-2']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Притягивающиеся половинки.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Притягивающиеся половинки» (имя .tex)
#     │    • problem_physics__10conduct_4: ответы -> ['1.24']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10conduct.zip
#     • Задач перепаковано: 4
#     • Удалено .html: 5
#     • Очищено answerinput: 4
#     • Результат: ./processed/physics__10conduct.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10cycle.zip
#   • Найдено задач: 4
#     ├─ Задача: Оптимальный прямоугольник.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Оптимальный прямоугольник» (имя .tex)
#     │    • problem_physics__10cycle_1: ответы -> ['67']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Изо-цикл.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Изо-цикл» (имя .tex)
#     │    • problem_physics__10cycle_2: ответы -> ['53']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Соединённые циклы.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Соединённые циклы» (имя .tex)
#     │    • problem_physics__10cycle_3: ответы -> ['43']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Треугольный цикл.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Треугольный цикл» (имя .tex)
#     │    • problem_physics__10cycle_4: ответы -> ['27']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10cycle.zip
#     • Задач перепаковано: 4
#     • Удалено .html: 5
#     • Очищено answerinput: 4
#     • Результат: ./processed/physics__10cycle.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10epsilon.zip
#   • Найдено задач: 2
#     ├─ Задача: Энергия в веществе.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Энергия в веществе» (имя .tex)
#     │    • problem_physics__10epsilon_1: ответы -> ['4']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Сила в конденсаторе.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Сила в конденсаторе» (имя .tex)
#     │    • problem_physics__10epsilon_2: ответы -> ['1800']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10epsilon.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10epsilon.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10equilibrium.zip
#   • Найдено задач: 2
#     ├─ Задача: Улёт заряда.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Улёт заряда» (имя .tex)
#     │    • problem_physics__10equilibrium_1: ответы -> ['-8']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Жидкая деревяшка.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Жидкая деревяшка» (имя .tex)
#     │    • problem_physics__10equilibrium_2: ответы -> ['0.79']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10equilibrium.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10equilibrium.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10ftl.zip
#   • Найдено задач: 3
#     ├─ Задача: Совпадающие изображения.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Совпадающие изображения» (имя .tex)
#     │    • problem_physics__10ftl_1: ответы -> ['21']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Три точки.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Три точки» (имя .tex)
#     │    • problem_physics__10ftl_2: ответы -> ['336']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Две перестановки.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Две перестановки» (имя .tex)
#     │    • problem_physics__10ftl_3: ответы -> ['-0.89']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10ftl.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10ftl.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10gauss.zip
#   • Найдено задач: 4
#     ├─ Задача: Рассчёт полей.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Рассчёт полей» (имя .tex)
#     │    • problem_physics__10gauss_1: ответы -> ['340', '720', '14', '9.4']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Выталкивание грани.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Выталкивание грани» (имя .tex)
#     │    • problem_physics__10gauss_2: ответы -> ['1.4']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Радиальное поле.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Радиальное поле» (имя .tex)
#     │    • problem_physics__10gauss_3: ответы -> ['360']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Поле отрезка.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Поле отрезка» (имя .tex)
#     │    • problem_physics__10gauss_4: ответы -> ['300']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10gauss.zip
#     • Задач перепаковано: 4
#     • Удалено .html: 5
#     • Очищено answerinput: 4
#     • Результат: ./processed/physics__10gauss.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10humid.zip
#   • Найдено задач: 3
#     ├─ Задача: Начальная влажность.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Начальная влажность» (имя .tex)
#     │    • problem_physics__10humid_1: ответы -> ['50']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Пружина и влажность.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Пружина и влажность» (имя .tex)
#     │    • problem_physics__10humid_2: ответы -> ['12.2']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Влажный воздух.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Влажный воздух» (имя .tex)
#     │    • problem_physics__10humid_3: ответы -> ['50']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10humid.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10humid.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10image.zip
#   • Найдено задач: 2
#     ├─ Задача: Изображение стержня.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Изображение стержня» (имя .tex)
#     │    • problem_physics__10image_1: ответы -> ['69']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Прямой уголок.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Прямой уголок» (имя .tex)
#     │    • problem_physics__10image_2: ответы -> ['1.85']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10image.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10image.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10karno.zip
#   • Найдено задач: 3
#     ├─ Задача: Теплопотери дома.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Теплопотери дома» (имя .tex)
#     │    • problem_physics__10karno_1: ответы -> ['0.53']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Части работы.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Части работы» (имя .tex)
#     │    • problem_physics__10karno_2: ответы -> ['7.5']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Граничный цикл.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Граничный цикл» (имя .tex)
#     │    • problem_physics__10karno_3: ответы -> ['5.7', '15.1']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10karno.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10karno.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10klapmend.zip
#   • Найдено задач: 3
#     ├─ Задача: Манометр.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Манометр» (имя .tex)
#     │    • problem_physics__10klapmend_1: ответы -> ['57']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Раздельный сосуд.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Раздельный сосуд» (имя .tex)
#     │    • problem_physics__10klapmend_2: ответы -> ['2.25']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Минимальная плотность.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Минимальная плотность» (имя .tex)
#     │    • problem_physics__10klapmend_3: ответы -> ['0.4']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10klapmend.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10klapmend.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10klau.zip
#   • Найдено задач: 1
#     ├─ Задача: Минимальная работа.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Минимальная работа» (имя .tex)
#     │    • problem_physics__10klau_1: ответы -> ['1.56']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10klau.zip
#     • Задач перепаковано: 1
#     • Удалено .html: 2
#     • Очищено answerinput: 1
#     • Результат: ./processed/physics__10klau.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10klin.zip
#   • Найдено задач: 3
#     ├─ Задача: Смещение в пластине.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Смещение в пластине» (имя .tex)
#     │    • problem_physics__10klin_1: ответы -> ['15']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Двойная призма.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Двойная призма» (имя .tex)
#     │    • problem_physics__10klin_2: ответы -> ['0.1']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Мини-призма.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Мини-призма» (имя .tex)
#     │    • problem_physics__10klin_3: ответы -> ['2.3']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10klin.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10klin.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10lambda.zip
#   • Найдено задач: 1
#     ├─ Задача: Чужой газ.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Чужой газ» (имя .tex)
#     │    • problem_physics__10lambda_1: ответы -> ['19.6', '2', '1.22', '118']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10lambda.zip
#     • Задач перепаковано: 1
#     • Удалено .html: 2
#     • Очищено answerinput: 1
#     • Результат: ./processed/physics__10lambda.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10lens.zip
#   • Найдено задач: 4
#     ├─ Задача: Поиск луча.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Поиск луча» (имя .tex)
#     │    • problem_physics__10lens_1: ответы -> ['Я решил задачу и уверен в своём решении; Я решил задачу, но не уверен; У меня есть идеи, но я в ступоре; У меня совсем нет идей']
#     │    • Удалено .html: 1
#     ├─ Задача: Поиск линзы.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Поиск линзы» (имя .tex)
#     │    • problem_physics__10lens_2: ответы -> ['Я решил задачу и уверен в своём решении; Я решил задачу, но не уверен; У меня есть идеи, но я в ступоре; У меня совсем нет идей']
#     │    • Удалено .html: 1
#     ├─ Задача: Изображение без линзы.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Изображение без линзы» (имя .tex)
#     │    • problem_physics__10lens_3: ответы -> ['Я решил задачу и уверен в своём решении; Я решил задачу, но не уверен; У меня есть идеи, но я в ступоре; У меня совсем нет идей', 'Я решил задачу и уверен в своём решении; Я решил задачу, но не уверен; У меня есть идеи, но я в ступоре; У меня совсем нет идей']
#     │    • Удалено .html: 1
#     ├─ Задача: Четыре звезды.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Четыре звезды» (имя .tex)
#     │    • problem_physics__10lens_4: ответы -> ['Я решил задачу и уверен в своём решении; Я решил задачу, но не уверен; У меня есть идеи, но я в ступоре; У меня совсем нет идей']
#     │    • Удалено .html: 1
#   ✓ Готово: physics__10lens.zip
#     • Задач перепаковано: 4
#     • Удалено .html: 5
#     • Очищено answerinput: 0
#     • Результат: ./processed/physics__10lens.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10log.zip
#   • Найдено задач: 2
#     ├─ Задача: Логарифмические махинации.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Логарифмические махинации» (имя .tex)
#     │    • problem_physics__10log_1: ответы -> ['1.4']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Экспоненциальная производная.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Экспоненциальная производная» (имя .tex)
#     │    • problem_physics__10log_2: ответы -> ['169']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10log.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10log.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10mirror.zip
#   • Найдено задач: 3
#     ├─ Задача: На складе.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «На складе» (имя .tex)
#     │    • problem_physics__10mirror_1: ответы -> ['33', '2']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Вращающееся зеркало.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Вращающееся зеркало» (имя .tex)
#     │    • problem_physics__10mirror_2: ответы -> ['0.6']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Муравей и зеркало.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Муравей и зеркало» (имя .tex)
#     │    • problem_physics__10mirror_3: ответы -> ['4']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10mirror.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10mirror.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10politropa.zip
#   • Найдено задач: 2
#     ├─ Задача: Степень объёма.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Степень объёма» (имя .tex)
#     │    • problem_physics__10politropa_1: ответы -> ['-2']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Большая работа.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Большая работа» (имя .tex)
#     │    • problem_physics__10politropa_2: ответы -> ['-0.75']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10politropa.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10politropa.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10pvo.zip
#   • Найдено задач: 3
#     ├─ Задача: 4.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «4» (имя .tex)
#     │    • problem_physics__10pvo_1: ответы -> ['60']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Оптическая планета.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Оптическая планета» (имя .tex)
#     │    • problem_physics__10pvo_2: ответы -> ['2.8']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Оптическая вращалка.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Оптическая вращалка» (имя .tex)
#     │    • problem_physics__10pvo_3: ответы -> ['0.8', '12']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10pvo.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10pvo.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10qen.zip
#   • Найдено задач: 4
#     ├─ Задача: Полусфера.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Полусфера» (имя .tex)
#     │    • problem_physics__10qen_1: ответы -> ['6.8']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Кубик.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Кубик» (имя .tex)
#     │    • problem_physics__10qen_2: ответы -> ['5']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Конус.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Конус» (имя .tex)
#     │    • problem_physics__10qen_3: ответы -> ['1.8', '0.014']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Металлическая сфера.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Металлическая сфера» (имя .tex)
#     │    • problem_physics__10qen_4: ответы -> ['-0.34', '-0.17']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10qen.zip
#     • Задач перепаковано: 4
#     • Удалено .html: 5
#     • Очищено answerinput: 4
#     • Результат: ./processed/physics__10qen.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10reflection.zip
#   • Найдено задач: 4
#     ├─ Задача: Призма на воде.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Призма на воде» (имя .tex)
#     │    • problem_physics__10reflection_1: ответы -> ['19']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Преломление в шаре.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Преломление в шаре» (имя .tex)
#     │    • problem_physics__10reflection_2: ответы -> ['1.67']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Прозрачный слой.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Прозрачный слой» (имя .tex)
#     │    • problem_physics__10reflection_3: ответы -> ['30', '30']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Толстая линза.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Толстая линза» (имя .tex)
#     │    • problem_physics__10reflection_4: ответы -> ['59']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10reflection.zip
#     • Задач перепаковано: 4
#     • Удалено .html: 5
#     • Очищено answerinput: 4
#     • Результат: ./processed/physics__10reflection.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10shadow.zip
#   • Найдено задач: 2
#     ├─ Задача: Тень палки.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Тень палки» (имя .tex)
#     │    • problem_physics__10shadow_1: ответы -> ['1.3']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Тень парня.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Тень парня» (имя .tex)
#     │    • problem_physics__10shadow_2: ответы -> ['2.3']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10shadow.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10shadow.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10small.zip
#   • Найдено задач: 3
#     ├─ Задача: Погрешность.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Погрешность» (имя .tex)
#     │    • problem_physics__10small_1: ответы -> ['1']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Ряд деления.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Ряд деления» (имя .tex)
#     │    • problem_physics__10small_2: ответы -> ['1', '0', '-0.17', '0', '0.0083']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Корень из ряда.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Корень из ряда» (имя .tex)
#     │    • problem_physics__10small_3: ответы -> ['1', '0', '-0.083', '0', '0.00069']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10small.zip
#     • Задач перепаковано: 3
#     • Удалено .html: 4
#     • Очищено answerinput: 3
#     • Результат: ./processed/physics__10small.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10system.zip
#   • Найдено задач: 1
#     ├─ Задача: Система сил.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Система сил» (имя .tex)
#     │    • problem_physics__10system_1: ответы -> ['0.33']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10system.zip
#     • Задач перепаковано: 1
#     • Удалено .html: 2
#     • Очищено answerinput: 1
#     • Результат: ./processed/physics__10system.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10tel.zip
#   • Найдено задач: 2
#     ├─ Задача: Грани.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Грани» (имя .tex)
#     │    • problem_physics__10tel_1: ответы -> ['2.09', '3.14', '1.57']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Цилиндры.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Цилиндры» (имя .tex)
#     │    • problem_physics__10tel_2: ответы -> ['6.28']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10tel.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10tel.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10turelec.zip
#   • Найдено задач: 5
#     ├─ Задача: Полусферы.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Полусферы» (имя .tex)
#     │    • problem_physics__10turelec_1: ответы -> ['20']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Электрический стержень.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Электрический стержень» (имя .tex)
#     │    • problem_physics__10turelec_2: ответы -> ['180', '3', '70.7']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Мудрый проводник.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Мудрый проводник» (имя .tex)
#     │    • problem_physics__10turelec_3: ответы -> ['-50']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Мини-проводник.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Мини-проводник» (имя .tex)
#     │    • problem_physics__10turelec_4: ответы -> ['0.71']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Изображение маятника.zip → 5.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Изображение маятника» (имя .tex)
#     │    • problem_physics__10turelec_5: ответы -> ['16.3']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10turelec.zip
#     • Задач перепаковано: 5
#     • Удалено .html: 6
#     • Очищено answerinput: 5
#     • Результат: ./processed/physics__10turelec.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10turopt.zip
#   • Найдено задач: 5
#     ├─ Задача: Прозрачный шар.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Прозрачный шар» (имя .tex)
#     │    • problem_physics__10turopt_1: ответы -> ['3.66', '3.3']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Чертеж в шкафу.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Чертеж в шкафу» (имя .tex)
#     │    • problem_physics__10turopt_2: ответы -> ['1']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Взгляд из торца.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Взгляд из торца» (имя .tex)
#     │    • problem_physics__10turopt_3: ответы -> ['71']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Сферическая среда.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Сферическая среда» (имя .tex)
#     │    • problem_physics__10turopt_4: ответы -> ['56.6']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Микроавтомобиль.zip → 5.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Микроавтомобиль» (имя .tex)
#     │    • problem_physics__10turopt_5: ответы -> ['53']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10turopt.zip
#     • Задач перепаковано: 5
#     • Удалено .html: 6
#     • Очищено answerinput: 5
#     • Результат: ./processed/physics__10turopt.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10turterm.zip
#   • Найдено задач: 5
#     ├─ Задача: Временной процесс.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Временной процесс» (имя .tex)
#     │    • problem_physics__10turterm_1: ответы -> ['320']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Гиря на сосуде.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Гиря на сосуде» (имя .tex)
#     │    • problem_physics__10turterm_2: ответы -> ['500']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Ромбик.zip → 3.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Ромбик» (имя .tex)
#     │    • problem_physics__10turterm_3: ответы -> ['300']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Влажный воздух.zip → 4.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Влажный воздух» (имя .tex)
#     │    • problem_physics__10turterm_4: ответы -> ['60.7']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: График теплоёмкости.zip → 5.zip
#     │    • .tex → main.tex
#     │    • name.txt: «График теплоёмкости» (имя .tex)
#     │    • problem_physics__10turterm_5: ответы -> ['28.5', '10.5', '400']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10turterm.zip
#     • Задач перепаковано: 5
#     • Удалено .html: 6
#     • Очищено answerinput: 5
#     • Результат: ./processed/physics__10turterm.zip
#
# ================================================================================
# 📦 Обработка архива: physics__10vdv.zip
#   • Найдено задач: 2
#     ├─ Задача: Клаузиус.zip → 1.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Клаузиус» (имя .tex)
#     │    • problem_physics__10vdv_1: ответы -> ['4.0']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#     ├─ Задача: Ван-дер-Ваальс.zip → 2.zip
#     │    • .tex → main.tex
#     │    • name.txt: «Ван-дер-Ваальс» (имя .tex)
#     │    • problem_physics__10vdv_2: ответы -> ['0.01']
#     │    • Удалено .html: 1
#     │    • Очищено answerinput: 1
#   ✓ Готово: physics__10vdv.zip
#     • Задач перепаковано: 2
#     • Удалено .html: 3
#     • Очищено answerinput: 2
#     • Результат: ./processed/physics__10vdv.zip
#
# ==================== ИТОГО ====================
# • Обработано архивов: 34
# • Всего задач: 97
# • Удалено .html всего: 131
# • Очищено answerinput: 92
# • Время: 0.50 c
# • Папка с результатом: ./processed
