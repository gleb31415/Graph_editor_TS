# %%
# -*- coding: utf-8 -*-
import zipfile, io, os, re, time, sys

# === Словарь ИМЕН ТОЛЬКО ДЛЯ 7 КЛАССА (как ты дал) ===
TASK_NAMES = {
    "physics__7.avgspd.zip": {
        "1": "Половинки",
        "2": "Катер",
        "3": "Плывем по течению",
        "4": "Смотрите под ноги",
        "5": "Бег по кругу",
        "6": "График средней скорости от пути",
        "7": "Бездорожье"
    },
    "physics__7.force.zip": {
        "1": "Перетягивание каната"
    },
    "physics__7arhimed.zip": {
        "1": "Шар повесили",
        "2": "Топим пластилином",
        "3": "На границе",
        "4": "Куб не тонет",
        "5": "Поплыли",
        "6": "Ледяные весы"
    },
    "physics__7friction.zip": {
        "1": "Куда везем мы кирпичи",
        "2": "Никак не сдвинуть",
        "3": "Снова ящик",
        "4": "Зажали"
    },
    "physics__7graphs.zip": {
        "Максимальная скорость": "Максимальная скорость",
        "Скорость от пути": "Скорость от пути",
        "Максимальное опережение": "Максимальное опережение",
        "Средняя скорость от пути": "Средняя скорость от пути"
    },
    "physics__7kinblok.zip": {
        "1": "Нить на блоке",
        "2": "Эвакуатор"
    },
    "physics__7mgN.zip": {
        "1": "Вес",
        "2": "Нормальная Реакция",
        "3": "Шары приятягиваются",
        "4": "Луннная гравитация",
        "5": "Солнце и земля"
    },
    "physics__7pressure.zip": {
        "1": "Давление мальчика",
        "2": "Большой столб",
        "3": "Масло и водица",
        "4": "Давить на воду",
        "5": "Намудрили",
        "6": "Пластилин на дне"
    },
    "physics__7rpo.zip": {
        "1": "Почти Феррари",
        "2": "Длинный поезд",
        "3": "График x(t)"
    },
    "physics__7springs.zip": {
        "1": "Растяжка",
        "2": "2 пружины последоваительно",
        "3": "теперь параллельно",
        "4": "2 хорошо, а 3 лучше",
        "5": "Разрезали поровну",
        "6": "Увеличиваем жесткость"
    },
    "physics__7statblock.zip": {
        "Два блока": "Два блока",
        "Змейкой": "Змейкой",
        "Ограниченное равновесие": "Ограниченное равновесие",
        "Лесенка": "Лесенка",
        "Намудрили": "Намудрили"
    },
    "physics__7torque.zip": {
        "1": "Равновесие",
        "2": "Груз на палке",
        "3": "Скизифова улитка",
        "4": "Соломинка",
        "5": "рычаг блок и нить"
    },
    "physics__7turmech.zip": {
        "Потерянная информация": "Потерянная информация",
        "Сила на дно": "Сила на дно",
        "Перемещение груза": "Перемещение груза",
        "Люди на рычагах": "Люди на рычагах",
        "Смещение груза": "Смещение груза"
    },
    "physics__7work.zip": {
        "1": "Работа крана",
        "2": "День на стройке",
        "3": "Полезный блок"
    }
}

SOURCE_DIR = "."
OUTPUT_DIR = "./processed"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# \answerinput{что-угодно} -> \answerinput{}
ANSWERINPUT_RE = re.compile(r'(\\answerinput)\s*\{[^}]*\}')

def clean_tex(content: str) -> str:
    return ANSWERINPUT_RE.sub(r'\1{}', content)

def is_html(name: str) -> bool:
    return name.lower().endswith(".html")

def rename_tex_to_main_zip(single_problem_zip: zipfile.ZipFile, new_zip: zipfile.ZipFile):
    """
    Копирует содержимое задачи, удаляя .html, переименовывая первый .tex -> main.tex
    и чистя \answerinput. Возвращает (new_main_path, orig_tex_basename, html_removed_count, cleaned_flag)
    """
    html_removed = 0
    cleaned_cnt = 0
    found_tex = None  # полный путь к исходному tex
    tex_basename_for_name = None

    # Сначала найдём первый .tex для переименования
    for nm in single_problem_zip.namelist():
        if nm.endswith("/") or is_html(nm):
            continue
        if nm.lower().endswith(".tex") and found_tex is None:
            found_tex = nm
            tex_basename_for_name = os.path.splitext(os.path.basename(nm))[0]

    # Теперь копируем все файлы с преобразованиями
    new_main_path = None
    for nm in single_problem_zip.namelist():
        if nm.endswith("/"):
            # каталоги можно пропустить — zip их создаст автоматически
            continue
        if is_html(nm):
            html_removed += 1
            continue

        data = single_problem_zip.read(nm)

        if nm == found_tex:
            # чистим \answerinput{..}
            try:
                text = data.decode("utf-8", errors="ignore")
            except Exception:
                text = data.decode("utf-8", errors="ignore")
            new_text = clean_tex(text)
            if new_text != text:
                cleaned_cnt += 1
            data = new_text.encode("utf-8")

            # переименовать в main.tex в той же директории
            dname = os.path.dirname(nm)
            new_main_path = os.path.join(dname, "main.tex") if dname else "main.tex"
            new_zip.writestr(new_main_path, data)
        else:
            # остальные файлы копируем как есть
            new_zip.writestr(nm, data)

    return new_main_path, tex_basename_for_name, html_removed, cleaned_cnt

def process_root_zip(root_zip_name: str):
    root_html_removed = 0
    inner_html_removed = 0
    tex_cleaned = 0
    tasks_written = 0

    root_zip_path = os.path.join(SOURCE_DIR, root_zip_name)
    print(f"\n================================================================================")
    print(f"📦 Обработка архива: {root_zip_name}")

    with zipfile.ZipFile(root_zip_path, 'r') as root_zip:
        # найти problems.zip (любой путь внутри zip)
        problems_member = next((nm for nm in root_zip.namelist() if nm.endswith("problems.zip")), None)
        if not problems_member:
            print("  ⚠️ problems.zip не найден — пропуск архива.")
            return (0, 0, 0, 0)

        # читаем исходный problems.zip
        problems_data = io.BytesIO(root_zip.read(problems_member))
        with zipfile.ZipFile(problems_data, 'r') as problems_zip:
            # отберём только задачи-архивы, сохранив порядок
            problem_zips = [p for p in problems_zip.namelist() if p.lower().endswith(".zip")]

            # если вдруг в самом problems.zip лежали .html — не копируем их
            html_in_problems = [p for p in problems_zip.namelist() if is_html(p)]
            inner_html_removed += len(html_in_problems)

            print(f"  • Найдено задач: {len(problem_zips)}")
            if html_in_problems:
                print(f"  • Удалено .html прямо в problems.zip: {len(html_in_problems)}")

            # соберём новый problems.zip
            new_problems_buffer = io.BytesIO()
            with zipfile.ZipFile(new_problems_buffer, 'w', compression=zipfile.ZIP_DEFLATED) as new_problems_zip:
                for idx, p in enumerate(problem_zips, start=1):
                    tasks_written += 1
                    inner_bytes = io.BytesIO(problems_zip.read(p))
                    with zipfile.ZipFile(inner_bytes, 'r') as single_problem_zip:
                        new_problem_buf = io.BytesIO()
                        with zipfile.ZipFile(new_problem_buf, 'w', compression=zipfile.ZIP_DEFLATED) as new_problem_zip:
                            new_main_path, tex_base, html_removed, cleaned_cnt = rename_tex_to_main_zip(
                                single_problem_zip, new_problem_zip
                            )
                            inner_html_removed += html_removed
                            tex_cleaned += cleaned_cnt

                            # имя задачи
                            mapping = TASK_NAMES.get(root_zip_name, {})
                            orig_key = os.path.splitext(os.path.basename(p))[0]
                            # если есть словарь для этого архива — берём оттуда; иначе — из имени .tex; fallback — имя zip
                            if mapping:
                                name_value = mapping.get(orig_key, tex_base or orig_key)
                                name_source = "словарь7" if orig_key in mapping else ("имя .tex" if tex_base else "имя zip")
                            else:
                                name_value = tex_base or orig_key
                                name_source = "имя .tex" if tex_base else "имя zip"

                            # служебные файлы
                            new_problem_zip.writestr("name.txt", name_value)
                            new_problem_zip.writestr("index.txt", str(idx))

                        # пишем в новый problems.zip под индексом
                        new_name = f"{idx}.zip"
                        new_problems_zip.writestr(new_name, new_problem_buf.getvalue())

                        # логи по задаче
                        print(f"    ├─ Задача: {p} → {new_name}")
                        if new_main_path:
                            print(f"    │    • .tex → {new_main_path} (переименование в main.tex)")
                        else:
                            print(f"    │    • ⚠️ .tex не найден (main.tex НЕ создан)")
                        print(f"    │    • name.txt: «{name_value}» (источник: {name_source})")
                        if html_removed:
                            print(f"    │    • Удалено .html внутри задачи: {html_removed}")
                        if cleaned_cnt:
                            print(f"    │    • Очищено \\answerinput{{...}} в .tex: {cleaned_cnt}")

            # пересобираем целевой корневой архив, удаляя .html ВЕЗДЕ
            out_zip_path = os.path.join(OUTPUT_DIR, root_zip_name)
            with zipfile.ZipFile(out_zip_path, 'w', compression=zipfile.ZIP_DEFLATED) as out_zip:
                for f in root_zip.namelist():
                    if is_html(f):
                        root_html_removed += 1
                        continue
                    if f == problems_member:
                        # заменяем на новый problems.zip
                        out_zip.writestr(f, new_problems_buffer.getvalue())
                    else:
                        out_zip.writestr(f, root_zip.read(f))

    # сводный лог по архиву
    print(f"  ✓ Готово: {root_zip_name}")
    print(f"    • Задач перепаковано: {tasks_written}")
    print(f"    • Удалено .html (корень): {root_html_removed}")
    print(f"    • Удалено .html (внутри problems/задач): {inner_html_removed}")
    print(f"    • Очищено \\answerinput: {tex_cleaned}")
    print(f"    • Результат: {os.path.join(OUTPUT_DIR, root_zip_name)}")

    return (1, tasks_written, root_html_removed + inner_html_removed, tex_cleaned)

def main():
    start = time.time()
    archives_total = 0
    tasks_total = 0
    html_removed_total = 0
    tex_cleaned_total = 0

    zips = [z for z in sorted(os.listdir(SOURCE_DIR)) if z.lower().endswith(".zip")]
    if not zips:
        print("⚠️ В каталоге нет .zip архивов.")
        return

    print(f"Найдено архивов: {len(zips)}. Выходная папка: {OUTPUT_DIR}")

    for z in zips:
        a, t, h, c = process_root_zip(z)
        archives_total += a
        tasks_total += t
        html_removed_total += h
        tex_cleaned_total += c

    print("\n==================== ИТОГО ====================")
    print(f"• Обработано архивов:   {archives_total}")
    print(f"• Всего задач:          {tasks_total}")
    print(f"• Удалено .html всего:  {html_removed_total}")
    print(f"• Очищено answerinput:  {tex_cleaned_total}")
    print(f"• Время:                {time.time()-start:.2f} c")
    print(f"• Папка с результатом:  {OUTPUT_DIR}")

if __name__ == "__main__":
    main()
# Out:
# 📦 Обработка physics__7.avgspd.zip
#   • Найдено задач: 7
#     • Задача 1.zip → 1.zip (name: Половинки)
#     • Задача 2.zip → 2.zip (name: Катер)
#     • Задача 3.zip → 3.zip (name: Плывем по течению)
#     • Задача 4.zip → 4.zip (name: Смотрите под ноги)
#     • Задача 5.zip → 5.zip (name: Бег по кругу)
#     • Задача 6.zip → 6.zip (name: График средней скорости от пути)
#     • Задача 7.zip → 7.zip (name: Бездорожье)
#
# 📦 Обработка physics__7.force.zip
#   • Найдено задач: 1
#     • Задача 1.zip → 1.zip (name: Перетягивание каната)
#
# 📦 Обработка physics__7arhimed.zip
#   • Найдено задач: 6
#     • Задача 1.zip → 1.zip (name: Шар повесили)
#     • Задача 2.zip → 2.zip (name: Топим пластилином)
#     • Задача 3.zip → 3.zip (name: На границе)
#     • Задача 4.zip → 4.zip (name: Куб не тонет)
#     • Задача 5.zip → 5.zip (name: Поплыли)
#     • Задача 6.zip → 6.zip (name: Ледяные весы)
#
# 📦 Обработка physics__7friction.zip
#   • Найдено задач: 4
#     • Задача 1.zip → 1.zip (name: Куда везем мы кирпичи)
#     • Задача 2.zip → 2.zip (name: Никак не сдвинуть)
#     • Задача 3.zip → 3.zip (name: Снова ящик)
#     • Задача 4.zip → 4.zip (name: Зажали)
#
# 📦 Обработка physics__7graphs.zip
#   • Найдено задач: 4
#     • Задача Максимальная скорость.zip → 1.zip (name: Максимальная скорость)
#     • Задача Скорость от пути.zip → 2.zip (name: Скорость от пути)
#     • Задача Максимальное опережение.zip → 3.zip (name: Максимальное опережение)
#     • Задача Средняя скорость от пути.zip → 4.zip (name: Средняя скорость от пути)
#
# 📦 Обработка physics__7kinblok.zip
#   • Найдено задач: 2
#     • Задача 1.zip → 1.zip (name: Нить на блоке)
#     • Задача 2.zip → 2.zip (name: Эвакуатор)
#
# 📦 Обработка physics__7mgN.zip
#   • Найдено задач: 5
#     • Задача 1.zip → 1.zip (name: Вес)
#     • Задача 2.zip → 2.zip (name: Нормальная Реакция)
#     • Задача 3.zip → 3.zip (name: Шары приятягиваются)
#     • Задача 4.zip → 4.zip (name: Луннная гравитация)
#     • Задача 5.zip → 5.zip (name: Солнце и земля)
#
# 📦 Обработка physics__7pressure.zip
#   • Найдено задач: 6
#     • Задача 1.zip → 1.zip (name: Давление мальчика)
#     • Задача 2.zip → 2.zip (name: Большой столб)
#     • Задача 3.zip → 3.zip (name: Масло и водица)
#     • Задача 4.zip → 4.zip (name: Давить на воду)
#     • Задача 5.zip → 5.zip (name: Намудрили)
#     • Задача 6.zip → 6.zip (name: Пластилин на дне)
#
# 📦 Обработка physics__7rpo.zip
#   • Найдено задач: 3
#     • Задача 1.zip → 1.zip (name: Почти Феррари)
#     • Задача 2.zip → 2.zip (name: Длинный поезд)
#     • Задача 3.zip → 3.zip (name: График x(t))
#
# 📦 Обработка physics__7springs.zip
#   • Найдено задач: 6
#     • Задача 1.zip → 1.zip (name: Растяжка)
#     • Задача 2.zip → 2.zip (name: 2 пружины последоваительно)
#     • Задача 3.zip → 3.zip (name: теперь параллельно)
#     • Задача 4.zip → 4.zip (name: 2 хорошо, а 3 лучше)
#     • Задача 5.zip → 5.zip (name: Разрезали поровну)
#     • Задача 6.zip → 6.zip (name: Увеличиваем жесткость)
#
# 📦 Обработка physics__7statblock.zip
#   • Найдено задач: 5
#     • Задача Два блока.zip → 1.zip (name: Два блока)
#     • Задача Змейкой.zip → 2.zip (name: Змейкой)
#     • Задача Ограниченное равновесие.zip → 3.zip (name: Ограниченное равновесие)
#     • Задача Лесенка.zip → 4.zip (name: Лесенка)
#     • Задача Намудрили.zip → 5.zip (name: Намудрили)
#
# 📦 Обработка physics__7torque.zip
#   • Найдено задач: 5
#     • Задача 1.zip → 1.zip (name: Равновесие)
#     • Задача 2.zip → 2.zip (name: Груз на палке)
#     • Задача 3.zip → 3.zip (name: Скизифова улитка)
#     • Задача 4.zip → 4.zip (name: Соломинка)
#     • Задача 5.zip → 5.zip (name: рычаг блок и нить)
#
# 📦 Обработка physics__7turmech.zip
#   • Найдено задач: 5
#     • Задача Потерянная информация.zip → 1.zip (name: Потерянная информация)
#     • Задача Сила на дно.zip → 2.zip (name: Сила на дно)
#     • Задача Перемещение груза.zip → 3.zip (name: Перемещение груза)
#     • Задача Люди на рычагах.zip → 4.zip (name: Люди на рычагах)
#     • Задача Смещение груза.zip → 5.zip (name: Смещение груза)
#
# 📦 Обработка physics__7work.zip
#   • Найдено задач: 3
#     • Задача 1.zip → 1.zip (name: Работа крана)
#     • Задача 2.zip → 2.zip (name: День на стройке)
#     • Задача 3.zip → 3.zip (name: Полезный блок)
#
# 📦 Обработка physics__8Energy.zip
#   • Найдено задач: 3
#     • Задача Грузы на блоке.zip → 1.zip (name: Грузы на блоке)
#     • Задача Работа на растяжение.zip → 2.zip (name: Работа на растяжение)
#     • Задача Скорость бруска.zip → 3.zip (name: Скорость бруска)
#
# 📦 Обработка physics__8MVP.zip
#   • Найдено задач: 4
#     • Задача Цепочка .zip → 1.zip (name: Цепочка )
#     • Задача Верёвка.zip → 2.zip (name: Верёвка)
#     • Задача Конус.zip → 3.zip (name: Конус)
#     • Задача Сложная система.zip → 4.zip (name: Сложная система)
#
# 📦 Обработка physics__8UI.zip
#   • Найдено задач: 3
#     • Задача Элементарный элемент.zip → 1.zip (name: Элементарный элемент)
#     • Задача Простая цепь.zip → 2.zip (name: Простая цепь)
#     • Задача Проволока.zip → 3.zip (name: Проволока)
#
# 📦 Обработка physics__8VAH.zip
#   • Найдено задач: 4
#     • Задача Неизвестный элемент.zip → 1.zip (name: Неизвестный элемент)
#     • Задача Ещё один.zip → 2.zip (name: Ещё один)
#     • Задача Нагрузочная прямая.zip → 3.zip (name: Нагрузочная прямая)
#     • Задача Диод в цепи.zip → 4.zip (name: Диод в цепи)
#
# 📦 Обработка physics__8bridge.zip
#   • Найдено задач: 3
#     • Задача Найти мост.zip → 1.zip (name: Найти мост)
#     • Задача Приборный мост.zip → 2.zip (name: Приборный мост)
#     • Задача Продолжение.zip → 3.zip (name: Продолжение)
#
# 📦 Обработка physics__8cmt.zip
#   • Найдено задач: 3
#     • Задача Изменения величин .zip → 1.zip (name: Изменения величин )
#     • Задача Теплота на превращение.zip → 2.zip (name: Теплота на превращение)
#     • Задача Разное сгорание.zip → 3.zip (name: Разное сгорание)
#
# 📦 Обработка physics__8equivist.zip
#   • Найдено задач: 4
#     • Задача Пример соединения.zip → 1.zip (name: Пример соединения)
#     • Задача Без источника.zip → 2.zip (name: Без источника)
#     • Задача То же самое.zip → 3.zip (name: То же самое)
#     • Задача Ошибочное подключение.zip → 4.zip (name: Ошибочное подключение)
#
# 📦 Обработка physics__8equivr.zip
#   • Найдено задач: 2
#     • Задача Первая цепочка.zip → 1.zip (name: Первая цепочка)
#     • Задача Вторая цепочка.zip → 2.zip (name: Вторая цепочка)
#
# 📦 Обработка physics__8expand.zip
#   • Найдено задач: 3
#     • Задача Две линейки.zip → 1.zip (name: Две линейки)
#     • Задача Объёмное расширение.zip → 2.zip (name: Объёмное расширение)
#     • Задача Дуга.zip → 3.zip (name: Дуга)
#
# 📦 Обработка physics__8humid.zip
#   • Найдено задач: 2
#     • Задача Относительная влажность.zip → 1.zip (name: Относительная влажность)
#     • Задача Табличные данные.zip → 2.zip (name: Табличные данные)
#
# 📦 Обработка physics__8infinite.zip
#   • Найдено задач: 2
#     • Задача Общий случай.zip → 1.zip (name: Общий случай)
#     • Задача Удвоение.zip → 2.zip (name: Удвоение)
#
# 📦 Обработка physics__8ist.zip
#   • Найдено задач: 1
#     • Задача Источная цепь.zip → 1.zip (name: Источная цепь)
#
# 📦 Обработка physics__8kirchhoff.zip
#   • Найдено задач: 4
#     • Задача Перемычка.zip → 1.zip (name: Перемычка)
#     • Задача Два источника.zip → 2.zip (name: Два источника)
#     • Задача Три источника.zip → 3.zip (name: Три источника)
#     • Задача Нетривиальное соединение.zip → 4.zip (name: Нетривиальное соединение)
#
# 📦 Обработка physics__8kulon.zip
#   • Найдено задач: 2
#     • Задача Изменение параметров.zip → 1.zip (name: Изменение параметров)
#     • Задача Суммарная сила.zip → 2.zip (name: Суммарная сила)
#
# 📦 Обработка physics__8loss.zip
#   • Найдено задач: 3
#     • Задача Ускорение кипения.zip → 1.zip (name: Ускорение кипения)
#     • Задача Ускорение плавления.zip → 2.zip (name: Ускорение плавления)
#     • Задача Теплопотери.zip → 3.zip (name: Теплопотери)
#
# 📦 Обработка physics__8measure.zip
#   • Найдено задач: 3
#     • Задача Амперметры.zip → 1.zip (name: Амперметры)
#     • Задача Вольтметры.zip → 2.zip (name: Вольтметры)
#     • Задача Омметры.zip → 3.zip (name: Омметры)
#
# 📦 Обработка physics__8naprpot.zip
#   • Найдено задач: 2
#     • Задача Разность потенциалов.zip → 1.zip (name: Разность потенциалов)
#     • Задача Левитирующий заряд.zip → 2.zip (name: Левитирующий заряд)
#
# 📦 Обработка physics__8om.zip
#   • Найдено задач: 4
#     • Задача Сравнение токов.zip → 1.zip (name: Сравнение токов)
#     • Задача Сравнение напряжений.zip → 2.zip (name: Сравнение напряжений)
#     • Задача Два резистора.zip → 3.zip (name: Два резистора)
#     • Задача Увеличение резистора.zip → 4.zip (name: Увеличение резистора)
#
# 📦 Обработка physics__8overlap.zip
#   • Найдено задач: 2
#     • Задача Похожий пример.zip → 1.zip (name: Похожий пример)
#     • Задача Треугольная сетка.zip → 2.zip (name: Треугольная сетка)
#
# 📦 Обработка physics__8rihman.zip
#   • Найдено задач: 2
#     • Задача Остывание кубов.zip → 1.zip (name: Остывание кубов)
#     • Задача Между слоями.zip → 2.zip (name: Между слоями)
#
# 📦 Обработка physics__8simm.zip
#   • Найдено задач: 4
#     • Задача Треугольник.zip → 1.zip (name: Треугольник)
#     • Задача Пятиугольник.zip → 2.zip (name: Пятиугольник)
#     • Задача Кубик .zip → 3.zip (name: Кубик )
#     • Задача Призма.zip → 4.zip (name: Призма)
#
# 📦 Обработка physics__8temperature.zip
#   • Найдено задач: 3
#     • Задача Гелий и аргон.zip → 1.zip (name: Гелий и аргон)
#     • Задача Нагревание газа.zip → 2.zip (name: Нагревание газа)
#     • Задача Средний квадрат.zip → 3.zip (name: Средний квадрат)
#
# 📦 Обработка physics__8trig.zip
#   • Найдено задач: 2
#     • Задача Тангенс через синус.zip → 1.zip (name: Тангенс через синус)
#     • Задача Большой угол.zip → 2.zip (name: Большой угол)
#
# 📦 Обработка physics__8tristar.zip
#   • Найдено задач: 2
#     • Задача Равные резисторы.zip → 1.zip (name: Равные резисторы)
#     • Задача Нетривиальное применение.zip → 2.zip (name: Нетривиальное применение)
#
# 📦 Обработка physics__8turelec.zip
#   • Найдено задач: 5
#     • Задача Резисторы из вещества.zip → 1.zip (name: Резисторы из вещества)
#     • Задача Эквивалентность.zip → 2.zip (name: Эквивалентность)
#     • Задача Трёхмерная цепь.zip → 3.zip (name: Трёхмерная цепь)
#     • Задача Приборная цепь.zip → 4.zip (name: Приборная цепь)
#     • Задача Мощность на резисторах.zip → 5.zip (name: Мощность на резисторах)
#
# 📦 Обработка physics__8turterm.zip
#   • Найдено задач: 5
#     • Задача Кипятильники.zip → 1.zip (name: Кипятильники)
#     • Задача Комбинированная задача.zip → 2.zip (name: Комбинированная задача)
#     • Задача Тонущая бутылка.zip → 3.zip (name: Тонущая бутылка)
#     • Задача Сублимация.zip → 4.zip (name: Сублимация)
#     • Задача Снег на фонаре.zip → 5.zip (name: Снег на фонаре)
#
# 📦 Обработка physics__8utb.zip
#   • Найдено задач: 3
#     • Задача Два тела.zip → 1.zip (name: Два тела)
#     • Задача Медная пластина.zip → 2.zip (name: Медная пластина)
#     • Задача Переливание.zip → 3.zip (name: Переливание)
#
# 📦 Обработка physics__9alpha.zip
#   • Найдено задач: 2
#     • Задача Полное ускорение.zip → 1.zip (name: Полное ускорение)
#     • Задача Радиус кривизны.zip → 2.zip (name: Радиус кривизны)
#
# 📦 Обработка physics__9ballvec.zip
#   • Найдено задач: 3
#     • Задача Камень.zip → 1.zip (name: Камень)
#     • Задача Озорные мышата.zip → 2.zip (name: Озорные мышата)
#     • Задача Осада Леопольда.zip → 3.zip (name: Осада Леопольда)
#
# 📦 Обработка physics__9bernulli.zip
#   • Найдено задач: 3
#     • Задача Изгиб.zip → 1.zip (name: Изгиб)
#     • Задача Бочка.zip → 2.zip (name: Бочка)
#     • Задача Вытекание жидкости.zip → 3.zip (name: Вытекание жидкости)
#
# 📦 Обработка physics__9centripetal.zip
#   • Найдено задач: 1
#     • Задача Поворот вектора.zip → 1.zip (name: Поворот вектора)
#
# 📦 Обработка physics__9coord.zip
#   • Найдено задач: 6
#     • Задача В четыре раза.zip → 1.zip (name: В четыре раза)
#     • Задача С высоты.zip → 2.zip (name: С высоты)
#     • Задача Угол к горизонту.zip → 3.zip (name: Угол к горизонту)
#     • Задача Пушка на склоне горы.zip → 4.zip (name: Пушка на склоне горы)
#     • Задача Винтовка.zip → 5.zip (name: Винтовка)
#     • Задача Кузнечик.zip → 6.zip (name: Кузнечик)
#
# 📦 Обработка physics__9derivative.zip
#   • Найдено задач: 5
#     • Задача Многочлен.zip → 1.zip (name: Многочлен)
#     • Задача Частное.zip → 2.zip (name: Частное)
#     • Задача Сложная функция.zip → 3.zip (name: Сложная функция)
#     • Задача Произведение.zip → 4.zip (name: Произведение)
#     • Задача Максимум.zip → 5.zip (name: Максимум)
#
# 📦 Обработка physics__9friction.zip
#   • Найдено задач: 3
#     • Задача Ускорение нити.zip → 1.zip (name: Ускорение нити)
#     • Задача Нить под углом.zip → 2.zip (name: Нить под углом)
#     • Задача Хула-хуп.zip → 3.zip (name: Хула-хуп)
#
# 📦 Обработка physics__9grav.zip
#   • Найдено задач: 3
#     • Задача Движение Луны.zip → 1.zip (name: Движение Луны)
#     • Задача Тёмная материя.zip → 2.zip (name: Тёмная материя)
#     • Задача Двойная звезда.zip → 3.zip (name: Двойная звезда)
#
# 📦 Обработка physics__9integral.zip
#   • Найдено задач: 5
#     • Задача Многочлен.zip → 1.zip (name: Многочлен)
#     • Задача Произведение.zip → 2.zip (name: Произведение)
#     • Задача Частное.zip → 3.zip (name: Частное)
#     • Задача Тригонометрия.zip → 4.zip (name: Тригонометрия)
#     • Задача Логарифм.zip → 5.zip (name: Логарифм)
#
# 📦 Обработка physics__9koenig.zip
#   • Найдено задач: 1
#     • Задача Санки.zip → 1.zip (name: Санки)
#
# 📦 Обработка physics__9mcv.zip
#   • Найдено задач: 3
#     • Задача Опять треугольная пластинка.zip → 1.zip (name: Опять треугольная пластинка)
#     • Задача Ступка с пестиком.zip → 2.zip (name: Ступка с пестиком)
#     • Задача Абсолютно твёрдое тело.zip → 3.zip (name: Абсолютно твёрдое тело)
#
# 📦 Обработка physics__9momentum.zip
#   • Найдено задач: 3
#     • Задача Отскок.zip → 1.zip (name: Отскок)
#     • Задача Нержиданный поворот.zip → 2.zip (name: Нержиданный поворот)
#     • Задача Соединённые резинкой.zip → 3.zip (name: Соединённые резинкой)
#
# 📦 Обработка physics__9mu.zip
#   • Найдено задач: 2
#     • Задача Расход топлива.zip → 1.zip (name: Расход топлива)
#     • Задача Максимум кинетической энергии.zip → 2.zip (name: Максимум кинетической энергии)
#
# 📦 Обработка physics__9newton.zip
#   • Найдено задач: 7
#     • Задача Связанные нитью.zip → 1.zip (name: Связанные нитью)
#     • Задача Центр масс.zip → 2.zip (name: Центр масс)
#     • Задача Сила под углом.zip → 3.zip (name: Сила под углом)
#     • Задача Три груза.zip → 4.zip (name: Три груза)
#     • Задача Кубик на доске.zip → 5.zip (name: Кубик на доске)
#     • Задача Перемещение.zip → 6.zip (name: Перемещение)
#     • Задача Платформа с выступом.zip → 7.zip (name: Платформа с выступом)
#
# 📦 Обработка physics__9noninert.zip
#   • Найдено задач: 4
#     • Задача Весы в лифте.zip → 1.zip (name: Весы в лифте)
#     • Задача Груз на пружине.zip → 2.zip (name: Груз на пружине)
#     • Задача Странные весы.zip → 3.zip (name: Странные весы)
#     • Задача Две шайбы.zip → 4.zip (name: Две шайбы)
#
# 📦 Обработка physics__9omega.zip
#   • Найдено задач: 5
#     • Задача Движение по окружности.zip → 1.zip (name: Движение по окружности)
#     • Задача Колесо автомобиля.zip → 2.zip (name: Колесо автомобиля)
#     • Задача Катушка.zip → 3.zip (name: Катушка)
#     • Задача Подшипник.zip → 4.zip (name: Подшипник)
#     • Задача Часы.zip → 5.zip (name: Часы)
#
# 📦 Обработка physics__9omegaso.zip
#   • Найдено задач: 5
#     • Задача Шарик на нити.zip → 1.zip (name: Шарик на нити)
#     • Задача Вращение массивной веревки.zip → 2.zip (name: Вращение массивной веревки)
#     • Задача Конический сосуд.zip → 3.zip (name: Конический сосуд)
#     • Задача По спирали.zip → 4.zip (name: По спирали)
#     • Задача Вращающийся сосуд.zip → 5.zip (name: Вращающийся сосуд)
#
# 📦 Обработка physics__9palka.zip
#   • Найдено задач: 5
#     • Задача У стенки.zip → 1.zip (name: У стенки)
#     • Задача Треугольная пластинка.zip → 2.zip (name: Треугольная пластинка)
#     • Задача А где палка?.zip → 3.zip (name: А где палка?)
#     • Задача У покосившейся стенки.zip → 4.zip (name: У покосившейся стенки)
#     • Задача Флажок.zip → 5.zip (name: Флажок)
#
# 📦 Обработка physics__9rud.zip
#   • Найдено задач: 5
#     • Задача Фонтан.zip → 1.zip (name: Фонтан)
#     • Задача Третья секунда.zip → 2.zip (name: Третья секунда)
#     • Задача Навстречу.zip → 3.zip (name: Навстречу)
#     • Задача Между опорами.zip → 4.zip (name: Между опорами)
#     • Задача Минимальный путь.zip → 5.zip (name: Минимальный путь)
#
# 📦 Обработка physics__9sound.zip
#   • Найдено задач: 3
#     • Задача Движение в воде.zip → 1.zip (name: Движение в воде)
#     • Задача Истребитель.zip → 2.zip (name: Истребитель)
#     • Задача Внутри конуса Маха.zip → 3.zip (name: Внутри конуса Маха)
#
# 📦 Обработка physics__9stokes.zip
#   • Найдено задач: 3
#     • Задача Карлсон.zip → 1.zip (name: Карлсон)
#     • Задача Вязкий валик.zip → 2.zip (name: Вязкий валик)
#     • Задача Валик на диске.zip → 3.zip (name: Валик на диске)
#
# 📦 Обработка physics__9trig.zip
#   • Найдено задач: 2
#     • Задача Угол треугольника.zip → 1.zip (name: Угол треугольника)
#     • Задача Упрощение.zip → 2.zip (name: Упрощение)
#
# 📦 Обработка physics__9turbal.zip
#   • Найдено задач: 5
#     • Задача Фейерверк.zip → 1.zip (name: Фейерверк)
#     • Задача Минимальное время.zip → 2.zip (name: Минимальное время)
#     • Задача Петарда.zip → 3.zip (name: Петарда)
#     • Задача Арка.zip → 4.zip (name: Арка)
#     • Задача Кузнец молодец.zip → 5.zip (name: Кузнец молодец)
#
# 📦 Обработка physics__9turdin.zip
#   • Найдено задач: 5
#     • Задача Звёзды на прямой.zip → 1.zip (name: Звёзды на прямой)
#     • Задача Водные лыжи.zip → 2.zip (name: Водные лыжи)
#     • Задача Катушка ниток.zip → 3.zip (name: Катушка ниток)
#     • Задача Шероховатая область.zip → 4.zip (name: Шероховатая область)
#     • Задача Вращающийся сосуд со стержнем.zip → 5.zip (name: Вращающийся сосуд со стержнем)
#
# 📦 Обработка physics__9turtverd.zip
#   • Найдено задач: 5
#     • Задача Геометрия в физике.zip → 1.zip (name: Геометрия в физике)
#     • Задача Связанные точки.zip → 2.zip (name: Связанные точки)
#     • Задача Система с блоками.zip → 3.zip (name: Система с блоками)
#     • Задача Клины.zip → 4.zip (name: Клины)
#     • Задача Вагонетка.zip → 5.zip (name: Вагонетка)
#
# 📦 Обработка physics__9turzs.zip
#   • Найдено задач: 5
#     • Задача Доски и шарики.zip → 1.zip (name: Доски и шарики)
#     • Задача Горка и шайба.zip → 2.zip (name: Горка и шайба)
#     • Задача Точное столкновение.zip → 3.zip (name: Точное столкновение)
#     • Задача Шарик и груз.zip → 4.zip (name: Шарик и груз)
#     • Задача Ускорение подставки.zip → 5.zip (name: Ускорение подставки)
#
# 📦 Обработка physics__9udar.zip
#   • Найдено задач: 4
#     • Задача Перпендикулярно.zip → 1.zip (name: Перпендикулярно)
#     • Задача Нагрев.zip → 2.zip (name: Нагрев)
#     • Задача Нецентральный удар.zip → 3.zip (name: Нецентральный удар)
#     • Задача Цепочка.zip → 4.zip (name: Цепочка)
#
# 📦 Обработка physics__9vector.zip
#   • Найдено задач: 3
#     • Задача Модуль суммы.zip → 1.zip (name: Модуль суммы)
#     • Задача Угол между векторами.zip → 2.zip (name: Угол между векторами)
#     • Задача Произведение.zip → 3.zip (name: Произведение)
#
# 📦 Обработка physics__9wall.zip
#   • Найдено задач: 3
#     • Задача Стенка.zip → 1.zip (name: Стенка)
#     • Задача Под углом.zip → 2.zip (name: Под углом)
#     • Задача Рикошетное столкновение.zip → 3.zip (name: Рикошетное столкновение)
#
# 📦 Обработка physics__mass.zip
#   • Найдено задач: 5
#     • Задача 1.zip → 1.zip (name: 1)
#     • Задача 2.zip → 2.zip (name: 2)
#     • Задача 3.zip → 3.zip (name: 3)
#     • Задача 4.zip → 4.zip (name: 4)
#     • Задача 5.zip → 5.zip (name: 5)
#
# ========== СВОДКА ==========
# • Обработано архивов: 71
# • Всего задач:        256
# • Удалено .html:      256
# • Очищено answerinput: 250
# • Результаты в:       ./processed
# • Время:              1.10 c
